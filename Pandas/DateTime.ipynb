# %%
import pandas as pd
import numpy as np

# %% [markdown]
# syntax wise datetime is very convenient
#
# but the performance takes a hit while working with huge data list vs numpy array
#
# the weaknesses of python datetime format inspried the numpy team to add a set of native time serirs data type to numpy
#
# the datatime64 dtype encodes dates as 64-bit integers and thus allows of dates to be represented very compactly

# %%
date=np.array("2026-06-27",dtype=np.datetime64)
date
# Out:
# array('2026-06-27', dtype='datetime64[D]')

# %% [markdown]
# DATAFRAME

# %%
#TABLE is also called as dataframe(2D structure of data consisting of rows and columns)->in a table every column as treted as a series and every row is treated as a record

# %%
import pandas as pd
import numpy as np

# %%
#using list
student_data=[
    [100,95,"15L"],
    [120,85,"20L"],
    [80,70,"8L"],
    [140,98,"50L"]]
pd.DataFrame(student_data,columns=["iq","marks","placement_package"])
# Out:
#     iq  marks placement_package
# 0  100     95               15L
# 1  120     85               20L
# 2   80     70                8L
# 3  140     98               50L

# %%
#using dictionary
student_dict={
    "name":["vijay","ajay","sanjay","suresh","ramesh","mahesh"],
    "iq":[95,89,70,98,100,40],
    "marks":[70,88,91,84,99,50],
    "placement_package":["15L","20L","8L","50L","30L","5L"]
}
pd.DataFrame(student_dict)
# Out:
#      name   iq  marks placement_package
# 0   vijay   95     70               15L
# 1    ajay   89     88               20L
# 2  sanjay   70     91                8L
# 3  suresh   98     84               50L
# 4  ramesh  100     99               30L
# 5  mahesh   40     50                5L

# %%
df1=pd.DataFrame(student_dict)

# %%
df1.set_index("name",inplace=True)

# %%
df1
# Out:
#          iq  marks placement_package
# name
# vijay    95     70               15L
# ajay     89     88               20L
# sanjay   70     91                8L
# suresh   98     84               50L
# ramesh  100     99               30L
# mahesh   40     50                5L

# %%
#using read_csv
movies=pd.read_csv("movies.csv")

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv("ipl-matches.csv")

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# DataFrame Attributes and Methods

# %%
#shape of dataframe
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#dtype of dataframe
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns of dataframe
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#values of dataframe
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#head and tail of dataframe
movies.head(5)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.tail(5)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
#sample of dataframe
ipl.sample(5)
# Out:
#           ID          City        Date Season  MatchNumber  \
# 845   392229  Johannesburg  2009-05-17   2009           49
# 698   548309        Jaipur  2012-04-06   2012            4
# 315  1082649     Bangalore  2017-05-19   2017  Qualifier 2
# 541   729299           NaN  2014-04-24   2014           11
# 848   392226  Bloemfontein  2009-05-15   2009           46
#
#                            Team1                  Team2  \
# 845              Deccan Chargers        Kings XI Punjab
# 698             Rajasthan Royals        Kings XI Punjab
# 315               Mumbai Indians  Kolkata Knight Riders
# 541  Royal Challengers Bangalore  Kolkata Knight Riders
# 848             Delhi Daredevils        Kings XI Punjab
#
#                        Venue                   TossWinner TossDecision  \
# 845    New Wanderers Stadium              Deccan Chargers        field
# 698   Sawai Mansingh Stadium              Kings XI Punjab        field
# ...

# %%
#info of dataframe
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe ->used to get the statistical summary of numeric columns in the dataframe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull->used to check the null values in the dataframe
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#duplicated ->used to check the duplicate values in the dataframe
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename is used to rename the columns of the dataframe
student_data
# Out:
# [[100, 95, '15L'], [120, 85, '20L'], [80, 70, '8L'], [140, 98, '50L']]

# %%
df=pd.DataFrame(student_data,columns=["iq","marks","placement_package"]) # convert list to dataframe

# %%
df.rename(columns={"iq":"intelligence","marks":"score","placement_package":"package"},inplace=True)

# %%
df
# Out:
#    intelligence  score package
# 0           100     95     15L
# 1           120     85     20L
# 2            80     70      8L
# 3           140     98     50L

# %% [markdown]
# math methods

# %%
#sum ->axis argument,min,max,mean,median,std,var,count ..ect
df.sum()
# Out:
# intelligence            440
# score                   348
# package         15L20L8L50L
# dtype: object

# %%
df.sum(axis=0) # for row wise sum
# Out:
# intelligence            440
# score                   348
# package         15L20L8L50L
# dtype: object

# %% [markdown]
# Selecting rows from a Dataframe

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#single cols
type(ipl["City"])
# Out:
# pandas.core.series.Series

# %%
#multiple cols
type(ipl[["Venue","TossWinner"]])
# Out:
# pandas.core.frame.DataFrame

# %%
(ipl[["Venue","TossWinner"]])
# Out:
#                                           Venue                   TossWinner
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
# [950 rows x 2 columns]

# %% [markdown]
# selecting rows from a dataframe

# %% [markdown]
# 1)iloc -> searches using index position
#
# 2)loc ->searches using index labels

# %%
#single row
df.iloc[0]
# Out:
# intelligence    100
# score            95
# package         15L
# Name: 0, dtype: object

# %%
ipl.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
#multiple rows
ipl.iloc[0:5]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.iloc[1:15:2]
# Out:
#          ID       City        Date Season  MatchNumber  \
# 1   1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 3   1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 5   1304115     Mumbai  2022-05-21   2022           69
# 7   1304113     Mumbai  2022-05-19   2022           67
# 9   1304111     Mumbai  2022-05-17   2022           65
# 11  1304109     Mumbai  2022-05-15   2022           63
# 13  1304107       Pune  2022-05-14   2022           61
#
#                           Team1                        Team2  \
# 1   Royal Challengers Bangalore             Rajasthan Royals
# 3              Rajasthan Royals               Gujarat Titans
# 5                Delhi Capitals               Mumbai Indians
# 7                Gujarat Titans  Royal Challengers Bangalore
# 9           Sunrisers Hyderabad               Mumbai Indians
# 11             Rajasthan Royals         Lucknow Super Giants
# 13        Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
#fancy indexing  -> there is no any pattern in the index
ipl.iloc[[0,4,7]]
# Out:
#         ID       City        Date Season MatchNumber                Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final     Rajasthan Royals
# 4  1304116     Mumbai  2022-05-22   2022          70  Sunrisers Hyderabad
# 7  1304113     Mumbai  2022-05-19   2022          67       Gujarat Titans
#
#                          Team2                             Venue  \
# 0               Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 4                 Punjab Kings          Wankhede Stadium, Mumbai
# 7  Royal Challengers Bangalore          Wankhede Stadium, Mumbai
#
#             TossWinner TossDecision SuperOver                  WinningTeam  \
# 0     Rajasthan Royals          bat         N               Gujarat Titans
# 4  Sunrisers Hyderabad          bat         N                 Punjab Kings
# 7       Gujarat Titans          bat         N  Royal Challengers Bangalore
#
#      WonBy  Margin method Player_of_Match  \
# 0  Wickets     7.0    NaN       HH Pandya
# ...

# %%
#loc
df1.loc["vijay"]
# Out:
# iq                    95
# marks                 70
# placement_package    15L
# Name: vijay, dtype: object

# %%
df1.loc["vijay":"suresh":2]# in loc range is inclusive
# Out:
#         iq  marks placement_package
# name
# vijay   95     70               15L
# sanjay  70     91                8L

# %%
df1
# Out:
#          iq  marks placement_package
# name
# vijay    95     70               15L
# ajay     89     88               20L
# sanjay   70     91                8L
# suresh   98     84               50L
# ramesh  100     99               30L
# mahesh   40     50                5L

# %% [markdown]
# selecting rows and columns

# %%
ipl.iloc[0:4,0:4] # only select top 4 rows and first 4 columns (note: iloc need index position)
# Out:
#         ID       City        Date Season
# 0  1312200  Ahmedabad  2022-05-29   2022
# 1  1312199  Ahmedabad  2022-05-27   2022
# 2  1312198    Kolkata  2022-05-25   2022
# 3  1312197    Kolkata  2022-05-24   2022

# %%
ipl.loc[0:4,"City":"Season"]#[actual nameof the columns and loc need index name]
# Out:
#         City        Date Season
# 0  Ahmedabad  2022-05-29   2022
# 1  Ahmedabad  2022-05-27   2022
# 2    Kolkata  2022-05-25   2022
# 3    Kolkata  2022-05-24   2022
# 4     Mumbai  2022-05-22   2022

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find the all final winners in the ipl matches with season
team=ipl["MatchNumber"]=="Final"
new_df=ipl[team][["Season","WinningTeam"]]
ipl[ipl["MatchNumber"]=="Final"][["Season","WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
new_df
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how may super over finishers are occured
ipl[ipl["SuperOver"]=='Y'].shape[0]
# Out:
# 14

# %%
#how many matches has csk won in kolkata
ipl.head(20)
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
ipl[(ipl["Venue"]=="Eden Gardens") & (ipl["WinningTeam"]=="Chennai Super Kings")].shape[0]
# Out:
# 5

# %%
ipl[(ipl["City"]=="Mumbai") & (ipl["WinningTeam"]=="Mumbai Indians")].shape[0]
# Out:
# 56

# %%
ipl[(ipl["City"]=="Navi Mumbai") & (ipl["WinningTeam"]=="Chennai Super Kings")].shape[0]
# Out:
# 2

# %%
#toss winner is match winner in percentage
ipl[ipl["TossWinner"]==ipl["WinningTeam"]].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
#movie with rating higher than 8 and votes>10000
movies[(movies["imdb_rating"]>8) & (movies["imdb_votes"]>10000)].shape
# Out:
# (43, 18)

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#Action movies with rating higher than 7.5 
mask1=movies["genres"].str.split("|").apply(lambda x:"Action" in x)
mask2=movies["imdb_rating"]>7.5

# %%
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
#write a function that can return the track record of 2 teams against each other

# %% [markdown]
# adding new columns

# %%
#completly new
movies["Country"]="India"

# %%
movies.head(5)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#create new columns withhelp of existing columns
item=movies.dropna()

# %%
item["lead actor"]=item["actors"].str.split("|").apply(lambda x:x[0])
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_28420\1568078030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   item["lead actor"]=item["actors"].str.split("|").apply(lambda x:x[0])

# %%
item.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# important Dataframe functions

# %%
#astype -> its reduce the size 
ipl["ID"]=ipl["ID"].astype("int32")

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

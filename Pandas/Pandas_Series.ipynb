# %%
#pandas is a fast ,powerful,,flexible and easy to useopen source data analysis and munipulation tool

# %%
#pandas series
# a pandas series is link a column in a table it is a 1D array holding data of any type

# %%
import pandas as pd
import numpy as np
# series from list
countries=["india","usa","japan","uk"]
pd.Series(countries)
# Out:
# 0    india
# 1      usa
# 2    japan
# 3       uk
# dtype: object

# %%
#integer series
runs=[2,48,40,100,40,20,40,20]
pd.Series(runs)
# Out:
# 0      2
# 1     48
# 2     40
# 3    100
# 4     40
# 5     20
# 6     40
# 7     20
# dtype: int64

# %%
#custom index
marks=[72,56,65,188,63]
subjects=["maths","physics","chemistry","EM","english"]
pd.Series(marks,index=subjects)
# Out:
# maths         72
# physics       56
# chemistry     65
# EM           188
# english       63
# dtype: int64

# %%
marks=pd.Series(marks,index=subjects,name="vijay marks in 12th class")

# %%
marks
# Out:
# maths         72
# physics       56
# chemistry     65
# EM           188
# english       63
# Name: vijay marks in 12th class, dtype: int64

# %% [markdown]
# Series DICT

# %%
marks={
    "math":72,
    "physics":56,
    "chemistry":65,
    "EM":188,
    "english":63
}
marks_series=pd.Series(marks,name="viajy marks in class 12th")
marks_series
# Out:
# math          72
# physics       56
# chemistry     65
# EM           188
# english       63
# Name: viajy marks in class 12th, dtype: int64

# %% [markdown]
# Series of attributes

# %%
#size
marks_series.size
# Out:
# 5

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'viajy marks in class 12th'

# %%
#is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,2,3,4,5,5]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['math', 'physics', 'chemistry', 'EM', 'english'], dtype='object')

# %%
#values
marks_series.values
# Out:
# array([ 72,  56,  65, 188,  63])

# %%
import pandas as pd

# %% [markdown]
# Series using read_csv

# %% [markdown]
# there are 3 datasets
#
# 1.subs.csv in which we have data of subcribes gain data around 365
#
# 2.kohli.csv in this dataset we have data about virat kohli scored runs in ipl
#
# 3.bollywood.csv in this dataset we have data about the movie name along with move hero

# %%
data=pd.read_csv("subs.csv")# convert dataframe to series
data=data.squeeze("columns")

# %%
data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data1=pd.read_csv("kohli_ipl.csv",index_col="match_no")
data1=data1.squeeze("columns")
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
data2=pd.read_csv("bollywood.csv",index_col="movie")
data2=data2.squeeze("columns")

# %%
data2
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# SERIES MATHODS

# %%
#head and tail
data.head(5)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
data1.head(5)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
data.tail(10)
# Out:
# 355    149
# 356    156
# 357    177
# 358    210
# 359    209
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
#sample (use  when you want to remove bais)
data2.sample(2)
# Out:
# movie
# Neal 'n' Nikki     Uday Chopra
# Singh Is Kinng    Akshay Kumar
# Name: lead, dtype: object

# %%
#value_counts ->movies (count the values present in the series
data2.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
#sort values 
data2.sort_values(ascending=True)
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
#its like chain mothods
data2.sort_values(ascending=True).head(7).values[6]
# Out:
# 'Aamir Khan'

# %%
data2=data2.copy()

# %%
data2.sort_values(inplace=True)

# %%
data2
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
#sort index based on index(alphabetically) for values we use sort_values
data2.sort_index(inplace=True)

# %%
data2=data2.copy()

# %%
data2.sort_values(ascending=False, inplace=True)

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# Series Meths Methods

# %%
#count total number of non null values in the series
data1.count()
# Out:
# np.int64(215)

# %%
#sum and product
data.sum()
# Out:
# np.int64(49510)

# %%
#mean,median,mode,std,var
#data.mean()
#data1.median()
#data2.mode()
data1.std()
data1.var()
# Out:
# np.float64(688.0024777222343)

# %%
#max and min
#data.min()
data.max()
# Out:
# np.int64(396)

# %%
data.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
data1.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# Series of data

# %%
#integer indexing
x=pd.Series([10,20,39,37,46,51,69,71,83])
x[1]
# Out:
# np.int64(20)

# %%
#negative indexing is not allowed in pandas series

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
data2[0]
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_8772\3942371460.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data2[0]
# 'Zulfi Sayed'

# %%
data2["Taj Mahal: An Eternal Love Story"]
# Out:
# 'Zulfi Sayed'

# %%
#slicing (fetch multiple items at a time)
data1[5:16]# 5 to 16
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
data[-5:]
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
data2[-4:]
# Out:
# movie
# Raat Gayi Baat Gayi?              Aamir Bashir
# Lipstick Under My Burkha          Aahana Kumra
# Roar: Tigers of the Sundarbans    Aadil Chahal
# Qaidi Band                          Aadar Jain
# Name: lead, dtype: object

# %%
#fancy indexing(we can get any random items from the series)
data1[[1,2,3,4,5]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
data1.iloc[-1]
# Out:
# np.int64(7)

# %%
data1[1]
# Out:
# np.int64(1)

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
data2[-1]
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_8772\461368272.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data2[-1]
# 'Aadar Jain'

# %% [markdown]
# Editing Series

# %%
#using indexing 
marks_series
# Out:
# math          72
# physics       56
# chemistry     65
# EM           188
# english       63
# Name: viajy marks in class 12th, dtype: int64

# %%
marks_series[1]=90
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_8772\595008200.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=90

# %%
marks_series
# Out:
# math          72
# physics       90
# chemistry     65
# EM           188
# english       63
# Name: viajy marks in class 12th, dtype: int64

# %%
#what if an index does not exist
# if that index is not present it will create a new index and assign the value to it
marks_series["evs"]=95
marks_series
# Out:
# math          72
# physics       90
# chemistry     65
# EM           188
# english       63
# evs           95
# Name: viajy marks in class 12th, dtype: int64

# %%
runs
# Out:
# [2, 48, 40, 100, 40, 20, 40, 20]

# %%
#slicing (edit multiple items at a time with the help of slicing)
runs[2:5]=[100,100]

# %%
runs
# Out:
# [2, 48, 100, 100, 20, 40, 20]

# %%
#funcy indexing

# %% [markdown]
# Series with pyhton functinalities

# %%
#len/type/dir/sorted/max/min
print(len(data))
print(type(data))
print(dir(data1))# tells about attributes and methods of the series
print(sorted(data))# output will be sorted in list form in ascending order
print(max(data))
print(min(data))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion (list ,dict)
marks_series
list(marks_series)
# Out:
# [72, 90, 65, 188, 63, 95]

# %%
marks_series
# Out:
# math          72
# physics       90
# chemistry     65
# EM           188
# english       63
# evs           95
# Name: viajy marks in class 12th, dtype: int64

# %%
dict(marks_series)
# Out:
# {'math': np.int64(72),
#  'physics': np.int64(90),
#  'chemistry': np.int64(65),
#  'EM': np.int64(188),
#  'english': np.int64(63),
#  'evs': np.int64(95)}

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
#membership operator (in) => in operators checks the index of the series not the values
"Taj Mahal: An Eternal Love Story" in data2
# Out:
# True

# %%
"Aadar Jain" in data2.values
# Out:
# True

# %%
#looping through a series (values)
for i in data2:
    print(i)
# Out:
# Zulfi Sayed
# Zeenat Aman
# Zeenat Aman
# Zeenat Aman
# Zeenat Aman
# Zayed Khan
# Zayed Khan
# Zayed Khan
# Zareen Khan
# Zara Sheikh
# Zaira Wasim
# Zaira Wasim
# Zaheer Iqbal
# Yudhveer Bakoliya
# Yogesh Raj Mishra
# Yashpal Sharma
# Yash Soni
# Yash Acharya
# Wamiqa Gabbi
# Waheeda Rehman
# Vivek Sudershan
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vivek Oberoi
# Vishwa Mohan Badola
# Vira Sathidar
# Vir Das
# Vipin Sharma
# Vinod Khanna
# Vinod Khanna
# Vinod Khanna
# Vinod Acharya
# Vinay Virmani
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Pathak
# Vinay Anand
# Vikrum Kumar
# Vikram Dasu
# Vikram Aditya
# Vikas Kalantri
# Vikaas Kalantari
# Vijay Varma
# Vijay Raaz
# Vijay Raaz
# Viineet Kumar
# Vidyut Jammwal
# Vidyut Jammwal
# Vidyut Jammwal
# Vidya Balan
# Vidya Balan
# ...

# %%
#arithmetic operations on series(broadcasting)
marks_series
# Out:
# math          72
# physics       90
# chemistry     65
# EM           188
# english       63
# evs           95
# Name: viajy marks in class 12th, dtype: int64

# %%
200-marks_series
# Out:
# math         128
# physics      110
# chemistry    135
# EM            12
# english      137
# evs          105
# Name: viajy marks in class 12th, dtype: int64

# %%
#relational operators(we will get boolean output)
data1>=50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# Boolean indexing on series

# %%
#find no of 50's and 100's in the series
#data1[data1>=50].size
data1[data1>=100].size
# Out:
# 5

# %%
#find the number of ducks
data1[data1==0].size
# Out:
# 9

# %%
#count number of days when we get 200 more than subcribers
data[data>=200].size
# Out:
# 59

# %%
#find the actors who have done more than 20 movies
num_movies=data2.value_counts()
num_movies>20
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# PLOTING GRAPH ON SERIES

# %%
data.plot()
# Out:
# <Axes: >

# %%
data2.value_counts().head(10).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# PRACTICE

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s[0])
# Out:
# 10

# %%
print(s[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Vijay\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 print(s[-1])
#
# File c:\Users\Vijay\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
# ...

# %%
#custum index
s1=pd.Series([10,20,30,60,70,80,90,100],index=['a','b','c','d','e','f','g','h'])

# %%
s1
# Out:
# a     10
# b     20
# c     30
# d     60
# e     70
# f     80
# g     90
# h    100
# dtype: int64

# %%
print(s[d])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 print(s[d])
#
# NameError: name 'd' is not defined

# %%
print(s[0])
# Out:
# 10

# %%
f1=pd.Series(['apple','banana','cherry','date','elderberry'],index=['f1','f2','f3','f4','f5'])
print(f1)
print(f1[0])
# Out:
# f1         apple
# f2        banana
# f3        cherry
# f4          date
# f5    elderberry
# dtype: object
# apple
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_19540\114920988.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f1[0])

# %% [markdown]
# Some imp Series Methods

# %%
data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
#astype
import sys
sys.getsizeof(data1)
# Out:
# 11752

# %%
data1.astype('int16') # we can change the data type of the series to int16 to save memory
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
sys.getsizeof(data1.astype("int16"))
# Out:
# 10462

# %%
#between ->its gives the output in boolean from if values are exist in between the given range
data1[data1.between(51,99)].size
# Out:
# 43

# %%
#clip -> it will clip the values in the given range if the value is less than 51 it will be replaced by 51 and if the value is greater than 99 it will be replaced by 99

# %%
#drop_duplicates -> it will drop the duplicate values from the series
temp=pd.Series([1,1,2,2,3,3,4,5])
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# 7    5
# dtype: int64

# %%
temp.size
# Out:
# 8

# %%
temp.duplicated().sum()
# Out:
# np.int64(3)

# %%
data2.duplicated().sum()
# Out:
# np.int64(934)

# %%
#deal with null values
temp1=pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp1
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp1.size
# Out:
# 10

# %%
temp1.count()
# Out:
# np.int64(7)

# %%
temp1.isnull().sum()
# Out:
# np.int64(3)

# %%
#dropna
temp1.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
#fillna
temp1.fillna(temp1.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
#isin -> it will check if the value is present in the series or not and it will return boolean output
data1[(data1==49) | (data1==99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
data1[data1.isin([49, 99])] # pass the list of values which you want to check in the series
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
data2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dil Toh Deewana Hai                  Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Talaash: The Answer Lies Within       Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
#apply
data2.apply(lambda x:x.split()[0].upper()) # it will split the string and take the first word and convert it to uppercase
# Out:
# movie
# Taj Mahal: An Eternal Love Story     ZULFI
# Strings of Passion                  ZEENAT
# Sallu Ki Shaadi                     ZEENAT
# Dil Toh Deewana Hai                 ZEENAT
# Dunno Y... Na Jaane Kyon            ZEENAT
#                                      ...
# Talaash: The Answer Lies Within      AAMIR
# Raat Gayi Baat Gayi?                 AAMIR
# Lipstick Under My Burkha            AAHANA
# Roar: Tigers of the Sundarbans       AADIL
# Qaidi Band                           AADAR
# Name: lead, Length: 1500, dtype: object

# %%
data1.apply(lambda x:"good day" if x>data1.mean() else "bad day") # it will check if the value is greater than mean it will return good day otherwise bad day
# Out:
# match_no
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
# 5       bad day
#          ...
# 211     bad day
# 212     bad day
# 213    good day
# 214     bad day
# 215     bad day
# Name: runs, Length: 215, dtype: object

# %%
#copy -> it will create a copy of the series and any changes made to the copy will not affect the original series
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new=data1.head(5).copy()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1]=100

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
data1
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
